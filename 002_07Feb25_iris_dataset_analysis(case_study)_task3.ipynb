# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanaTejaDumpa/pandas_practise/blob/main/002_07Feb25_iris_dataset_analysis(case_study)_task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 07/02/2025

# %% [markdown]
# # <center><u><b>Pandas Case Study: Iris Dataset Analysis</b></u></center>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### importing "iris" dataset

# %%
data = pd.read_csv("iris_dataset.csv")
data
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#              target
# ...

# %% [markdown]
# ### Q1. Rename the columns of the dataset to 'SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', and 'Species'.

# %%
data.columns = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth', 'Species']
data
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Q2.
# a) Set the index of the DataFrame to the 'Species' column.
#
# b) Retrieve the first 10 rows of the DataFrame using integer-based indexing.

# %%
# a) # using Species column as index

data.set_index('Species', inplace = True)
data
# Out:
#                 SepalLength  SepalWidth  PetalLength  PetalWidth
# Species
# Iris-setosa             5.1         3.5          1.4         0.2
# Iris-setosa             4.9         3.0          1.4         0.2
# Iris-setosa             4.7         3.2          1.3         0.2
# Iris-setosa             4.6         3.1          1.5         0.2
# Iris-setosa             5.0         3.6          1.4         0.2
# ...                     ...         ...          ...         ...
# Iris-virginica          6.7         3.0          5.2         2.3
# Iris-virginica          6.3         2.5          5.0         1.9
# Iris-virginica          6.5         3.0          5.2         2.0
# Iris-virginica          6.2         3.4          5.4         2.3
# Iris-virginica          5.9         3.0          5.1         1.8
#
# [150 rows x 4 columns]

# %%
# b) Retrieving first 10 rows of dataframe using integer-based indexing
data.iloc[0:10,0:5]
# Out:
#              SepalLength  SepalWidth  PetalLength  PetalWidth
# Species
# Iris-setosa          5.1         3.5          1.4         0.2
# Iris-setosa          4.9         3.0          1.4         0.2
# Iris-setosa          4.7         3.2          1.3         0.2
# Iris-setosa          4.6         3.1          1.5         0.2
# Iris-setosa          5.0         3.6          1.4         0.2
# Iris-setosa          5.4         3.9          1.7         0.4
# Iris-setosa          4.6         3.4          1.4         0.3
# Iris-setosa          5.0         3.4          1.5         0.2
# Iris-setosa          4.4         2.9          1.4         0.2
# Iris-setosa          4.9         3.1          1.5         0.1

# %% [markdown]
# ### Q3.
# a)Slice the DataFrame to display rows with 'PetalWidth' greater than 2.5.
#
# b)Slice the DataFrame to display columns 'SepalLength' and 'SepalWidth' for the first 5 rows.

# %%
# a) displaying rows with petal width greater than 2.5

data[data['PetalWidth']>2.5]
# Out:
# Empty DataFrame
# Columns: [SepalLength, SepalWidth, PetalLength, PetalWidth]
# Index: []

# %%
# b) displaying first 5 rows containing Sepal length and sepal width columns

data.iloc[0:5,0:2]
# Out:
#              SepalLength  SepalWidth
# Species
# Iris-setosa          5.1         3.5
# Iris-setosa          4.9         3.0
# Iris-setosa          4.7         3.2
# Iris-setosa          4.6         3.1
# Iris-setosa          5.0         3.6

# %% [markdown]
# ### Q4.
# a) Filter the DataFrame to show only rows where 'Species' is 'versicolor'.
#
# b) Filter the DataFrame to show rows where 'PetalLength' is greater than 4 and 'SepalWidth' is less than 3.

# %%
# a)showing only rows where species is vercicolor
data[data.index == 'Iris-versicolor']
# Out:
#                  SepalLength  SepalWidth  PetalLength  PetalWidth  PetalArea
# Species
# Iris-versicolor     7.000000         3.2          4.7         1.4       6.58
# Iris-versicolor     6.398438         3.2          4.5         1.5       6.75
# Iris-versicolor     6.898438         3.1          4.9         1.5       7.35
# Iris-versicolor     5.500000         2.3          4.0         1.3       5.20
# Iris-versicolor     6.500000         2.8          4.6         1.5       6.90
# Iris-versicolor     5.699219         2.8          4.5         1.3       5.85
# Iris-versicolor     6.300781         3.3          4.7         1.6       7.52
# Iris-versicolor     4.898438         2.4          3.3         1.0       3.30
# Iris-versicolor     6.601562         2.9          4.6         1.3       5.98
# Iris-versicolor     5.199219         2.7          3.9         1.4       5.46
# Iris-versicolor     5.000000         2.0          3.5         1.0       3.50
# ...

# %%
# b) showing rows where petal length is greater than 4 and sepal width is less than 3

data[(data['PetalLength']>4) & (data['SepalWidth']<3)]
# Out:
#                  SepalLength  SepalWidth  PetalLength  PetalWidth
# Species
# Iris-versicolor          6.5         2.8          4.6         1.5
# Iris-versicolor          5.7         2.8          4.5         1.3
# Iris-versicolor          6.6         2.9          4.6         1.3
# Iris-versicolor          6.1         2.9          4.7         1.4
# Iris-versicolor          5.8         2.7          4.1         1.0
# Iris-versicolor          6.2         2.2          4.5         1.5
# Iris-versicolor          6.3         2.5          4.9         1.5
# Iris-versicolor          6.1         2.8          4.7         1.2
# Iris-versicolor          6.4         2.9          4.3         1.3
# Iris-versicolor          6.8         2.8          4.8         1.4
# Iris-versicolor          6.0         2.9          4.5         1.5
# Iris-versicolor          6.0         2.7          5.1         1.6
# Iris-versicolor          6.3         2.3          4.4         1.3
# ...

# %% [markdown]
# ### Q5.
# a)Calculate the minimum 'PetalLength' across all species.
#
# b)Calculate the maximum 'SepalWidth' across all species.

# %%
# a) calculating the minimum petal length
data['PetalLength'].min()
# Out:
# 1.0

# %%
# b) calculating the maximum sepal width

data['SepalWidth'].max()
# Out:
# 4.4

# %% [markdown]
# ### Q6.
# a) Calculate the sum of values along axis=1 (row-wise).
#
# b) Calculate the mean of values along axis=0 (column-wise).

# %%
# a) calculating sum of values along row-wise(axis = 1)

data.sum(axis = 1)
# Out:
# Species
# Iris-setosa       10.2
# Iris-setosa        9.5
# Iris-setosa        9.4
# Iris-setosa        9.4
# Iris-setosa       10.2
#                   ...
# Iris-virginica    17.2
# Iris-virginica    15.7
# Iris-virginica    16.7
# Iris-virginica    17.3
# Iris-virginica    15.8
# Length: 150, dtype: float64

# %%
# b) calculating the mean of values column wise(axis = 0)
data.mean(axis = 0)
# Out:
# SepalLength    5.843333
# SepalWidth     3.054000
# PetalLength    3.758667
# PetalWidth     1.198667
# dtype: float64

# %% [markdown]
# ### Q7. Add a new column 'PetalArea' calculated as the product of 'PetalLength' and 'PetalWidth'.

# %%
data['PetalArea'] = data['PetalLength']*data['PetalWidth']
data
# Out:
#                 SepalLength  SepalWidth  PetalLength  PetalWidth  PetalArea
# Species
# Iris-setosa             5.1         3.5          1.4         0.2       0.28
# Iris-setosa             4.9         3.0          1.4         0.2       0.28
# Iris-setosa             4.7         3.2          1.3         0.2       0.26
# Iris-setosa             4.6         3.1          1.5         0.2       0.30
# Iris-setosa             5.0         3.6          1.4         0.2       0.28
# ...                     ...         ...          ...         ...        ...
# Iris-virginica          6.7         3.0          5.2         2.3      11.96
# Iris-virginica          6.3         2.5          5.0         1.9       9.50
# Iris-virginica          6.5         3.0          5.2         2.0      10.40
# Iris-virginica          6.2         3.4          5.4         2.3      12.42
# Iris-virginica          5.9         3.0          5.1         1.8       9.18
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Q8. Convert the 'SepalLength' column to float dtype using astype.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, Iris-setosa to Iris-virginica
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float64
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   PetalArea    150 non-null    float64
# dtypes: float64(5)
# memory usage: 11.1+ KB

# %%
data['SepalLength'] = data['SepalLength'].astype('float16')
data
# Out:
#                 SepalLength  SepalWidth  PetalLength  PetalWidth  PetalArea
# Species
# Iris-setosa        5.101562         3.5          1.4         0.2       0.28
# Iris-setosa        4.898438         3.0          1.4         0.2       0.28
# Iris-setosa        4.699219         3.2          1.3         0.2       0.26
# Iris-setosa        4.601562         3.1          1.5         0.2       0.30
# Iris-setosa        5.000000         3.6          1.4         0.2       0.28
# ...                     ...         ...          ...         ...        ...
# Iris-virginica     6.699219         3.0          5.2         2.3      11.96
# Iris-virginica     6.300781         2.5          5.0         1.9       9.50
# Iris-virginica     6.500000         3.0          5.2         2.0      10.40
# Iris-virginica     6.199219         3.4          5.4         2.3      12.42
# Iris-virginica     5.898438         3.0          5.1         1.8       9.18
#
# [150 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, Iris-setosa to Iris-virginica
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  150 non-null    float16
#  1   SepalWidth   150 non-null    float64
#  2   PetalLength  150 non-null    float64
#  3   PetalWidth   150 non-null    float64
#  4   PetalArea    150 non-null    float64
# dtypes: float16(1), float64(4)
# memory usage: 10.2+ KB

# %% [markdown]
# ### Q9. Query the DataFrame to show rows where 'PetalLength' is greater than 'SepalLength'.

# %%
data[data['PetalLength']>data['SepalLength']]
# Out:
# Empty DataFrame
# Columns: [SepalLength, SepalWidth, PetalLength, PetalWidth, PetalArea]
# Index: []

# %% [markdown]
# ### Q10. Apply a function to calculate the difference between 'PetalLength' and 'SepalLength' for each row.

# %%
 data['PetalLength']-data['SepalLength']
# Out:
# Species
# Iris-setosa      -3.701563
# Iris-setosa      -3.498438
# Iris-setosa      -3.399219
# Iris-setosa      -3.101562
# Iris-setosa      -3.600000
#                     ...
# Iris-virginica   -1.499219
# Iris-virginica   -1.300781
# Iris-virginica   -1.300000
# Iris-virginica   -0.799219
# Iris-virginica   -0.798438
# Length: 150, dtype: float64

# %% [markdown]
# ### Q11.
# a) Find the top 3 rows with the largest 'PetalLength'.
#
# b) Find the top 3 rows with the smallest 'SepalWidth'.

# %%
# a) Finding the top 3 rows with the largest 'PetalLength'
data['PetalLength'].sort_values(ascending = False).head(3)
# Out:
# Species
# Iris-virginica    6.9
# Iris-virginica    6.7
# Iris-virginica    6.7
# Name: PetalLength, dtype: float64

# %%
# b) Finding the top 3 rows with the smallest Sepal width
data['SepalWidth'].sort_values().head(3)
# Out:
# Species
# Iris-versicolor    2.0
# Iris-versicolor    2.2
# Iris-virginica     2.2
# Name: SepalWidth, dtype: float64

# %% [markdown]
# ### Q12.
# a) Sort the DataFrame by 'PetalWidth' in ascending order.
#
# b) Sort the DataFrame by 'SepalLength' in descending order.

# %%
# a) Sorting the dataframe by petal width in ascending order

data.sort_values(by = 'PetalWidth')
# Out:
#                 SepalLength  SepalWidth  PetalLength  PetalWidth  PetalArea
# Species
# Iris-setosa        5.199219         4.1          1.5         0.1       0.15
# Iris-setosa        4.300781         3.0          1.1         0.1       0.11
# Iris-setosa        4.898438         3.1          1.5         0.1       0.15
# Iris-setosa        4.898438         3.1          1.5         0.1       0.15
# Iris-setosa        4.800781         3.0          1.4         0.1       0.14
# ...                     ...         ...          ...         ...        ...
# Iris-virginica     6.699219         3.1          5.6         2.4      13.44
# Iris-virginica     5.800781         2.8          5.1         2.4      12.24
# Iris-virginica     6.300781         3.3          6.0         2.5      15.00
# Iris-virginica     6.699219         3.3          5.7         2.5      14.25
# Iris-virginica     7.199219         3.6          6.1         2.5      15.25
#
# [150 rows x 5 columns]

# %%
# b) sorting the dataframe by sepal length in descending order
data.sort_values(by = 'SepalLength',ascending = False)
# Out:
#                 SepalLength  SepalWidth  PetalLength  PetalWidth  PetalArea
# Species
# Iris-virginica     7.898438         3.8          6.4         2.0      12.80
# Iris-virginica     7.699219         3.0          6.1         2.3      14.03
# Iris-virginica     7.699219         2.8          6.7         2.0      13.40
# Iris-virginica     7.699219         3.8          6.7         2.2      14.74
# Iris-virginica     7.699219         2.6          6.9         2.3      15.87
# ...                     ...         ...          ...         ...        ...
# Iris-setosa        4.500000         2.3          1.3         0.3       0.39
# Iris-setosa        4.398438         3.2          1.3         0.2       0.26
# Iris-setosa        4.398438         3.0          1.3         0.2       0.26
# Iris-setosa        4.398438         2.9          1.4         0.2       0.28
# Iris-setosa        4.300781         3.0          1.1         0.1       0.11
#
# [150 rows x 5 columns]
