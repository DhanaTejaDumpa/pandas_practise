# %% [markdown]
# <a href="https://colab.research.google.com/github/DhanaTejaDumpa/pandas_practise/blob/main/pandas_assignment_day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %% [markdown]
# ##### Write a Pandas program to create a dataframe by given dictionary and index as lables

# %%
### code here
df = pd.DataFrame(data,index = labels)
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %% [markdown]
# ##### 1. Write a Pandas program to sort the DataFrame first by 'name' in descending order, then by 'score' in ascending order

# %%
### code here
df.sort_values(by = ['name','score'],ascending=[False,True])
# Out:
#         name  score  attempts qualify
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# c  Katherine   16.5         2     yes
# j      Jonas   19.0         1     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# b       Dima    9.0         3      no
# a  Anastasia   12.5         1     yes

# %% [markdown]
# ###### 2. Write a Pandas program to replace the 'qualify' column contains the values 'yes' and 'no' with True and False

# %%
### code here
df.replace({'qualify':{'yes':True,'no':False}})
# Out:
# <ipython-input-38-919d734896eb>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'qualify':{'yes':True,'no':False}})
#         name  score  attempts  qualify
# a  Anastasia   12.5         1     True
# b       Dima    9.0         3    False
# c  Katherine   16.5         2     True
# d      James    NaN         3    False
# e      Emily    9.0         2    False
# f    Michael   20.0         3     True
# g    Matthew   14.5         1     True
# h      Laura    NaN         1    False
# i      Kevin    8.0         2    False
# j      Jonas   19.0         1     True

# %%
# alternative method
df['qualify'] = np.where(df['qualify']=='yes',True,False)

# %% [markdown]
# #####3. Write a Pandas program to delete the 'attempts' column from the DataFrame

# %%
### code here
df.drop(columns=['attempts'],inplace=True)
df
# Out:
#         name  score qualify
# a  Anastasia   12.5     yes
# b       Dima    9.0      no
# c  Katherine   16.5     yes
# d      James    NaN      no
# e      Emily    9.0      no
# f    Michael   20.0     yes
# g    Matthew   14.5     yes
# h      Laura    NaN      no
# i      Kevin    8.0      no
# j      Jonas   19.0     yes

# %% [markdown]
# ##### 4. Write a Pandas program to insert a new column in existing DataFrame.

# %%
### code here
df['new_column'] = np.nan
df
# Out:
#         name  score qualify  new_column
# a  Anastasia   12.5     yes         NaN
# b       Dima    9.0      no         NaN
# c  Katherine   16.5     yes         NaN
# d      James    NaN      no         NaN
# e      Emily    9.0      no         NaN
# f    Michael   20.0     yes         NaN
# g    Matthew   14.5     yes         NaN
# h      Laura    NaN      no         NaN
# i      Kevin    8.0      no         NaN
# j      Jonas   19.0     yes         NaN

# %% [markdown]
# ##### 5. Write a Pandas program to change the name 'James' to 'Maxwell' in name column of the DataFrame.

# %%
### code here
df['name'].replace(to_replace='James',value='Maxwell',inplace = True)
df
# Out:
# <ipython-input-41-d4efc74f7e44>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['name'].replace(to_replace='James',value='Maxwell',inplace = True)
#         name  score qualify  new_column
# a  Anastasia   12.5     yes         NaN
# b       Dima    9.0      no         NaN
# c  Katherine   16.5     yes         NaN
# d    Maxwell    NaN      no         NaN
# e      Emily    9.0      no         NaN
# f    Michael   20.0     yes         NaN
# g    Matthew   14.5     yes         NaN
# h      Laura    NaN      no         NaN
# i      Kevin    8.0      no         NaN
# j      Jonas   19.0     yes         NaN

# %% [markdown]
# ##### 6. Write a Pandas program to rename columns of a given DataFrame

# %%
### code here
df.rename(columns={'new_column':'unnamed'},inplace = True)
df
# Out:
#         name  score qualify  unnamed
# a  Anastasia   12.5     yes      NaN
# b       Dima    9.0      no      NaN
# c  Katherine   16.5     yes      NaN
# d    Maxwell    NaN      no      NaN
# e      Emily    9.0      no      NaN
# f    Michael   20.0     yes      NaN
# g    Matthew   14.5     yes      NaN
# h      Laura    NaN      no      NaN
# i      Kevin    8.0      no      NaN
# j      Jonas   19.0     yes      NaN

# %% [markdown]
# ##### 7. Write a Pandas program to convert the datatype of a given column (floats to ints).

# %%
### code here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     10 non-null     object
#  1   score    8 non-null      float64
#  2   qualify  10 non-null     object
#  3   unnamed  0 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 700.0+ bytes

# %%
df['score'] = df['score'].fillna(0)
df['score'] = df['score'].astype(int)
df['unnamed'] = df['unnamed'].fillna(0)
df['unnamed'] = df['unnamed'].astype(int)

# %%
# alternative method
df[['score', 'unnamed']] = df[['score', 'unnamed']].fillna(0).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   name     10 non-null     object
#  1   score    10 non-null     int64
#  2   qualify  10 non-null     object
#  3   unnamed  10 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 700.0+ bytes

# %% [markdown]
# ###### 8.  Write a Pandas program to convert index in a column of the given dataframe.

# %%
### code here
df.reset_index(inplace=True)
df
# Out:
#   index       name  score qualify  unnamed
# 0     a  Anastasia     12     yes        0
# 1     b       Dima      9      no        0
# 2     c  Katherine     16     yes        0
# 3     d    Maxwell      0      no        0
# 4     e      Emily      9      no        0
# 5     f    Michael     20     yes        0
# 6     g    Matthew     14     yes        0
# 7     h      Laura      0      no        0
# 8     i      Kevin      8      no        0
# 9     j      Jonas     19     yes        0

# %% [markdown]
# ##### 9. Write a Pandas program to shuffle a DataFrame rows.

# %%
### code here
shuffled_df = df.sample(frac=1)
shuffled_df
# Out:
#   index       name  score qualify  unnamed
# 9     j      Jonas     19     yes        0
# 6     g    Matthew     14     yes        0
# 7     h      Laura      0      no        0
# 4     e      Emily      9      no        0
# 0     a  Anastasia     12     yes        0
# 2     c  Katherine     16     yes        0
# 1     b       Dima      9      no        0
# 8     i      Kevin      8      no        0
# 5     f    Michael     20     yes        0
# 3     d    Maxwell      0      no        0

# %% [markdown]
# ##### 10 Write a Pandas program to write a DataFrame to CSV file using tab separator

# %%
### code here
df.to_csv('data.csv', sep='\t', index=False)

# %%
student_data1 = pd.DataFrame({
        'student_id': ['S1', 'S2', 'S3', 'S4', 'S5'],
         'name': ['Danniella Fenton', 'Ryder Storey', 'Bryce Jensen', 'Ed Bernal', 'Kwame Morin'],
        'marks': [200, 210, 190, 222, 199]})

student_data2 = pd.DataFrame({
        'student_id': ['S4', 'S5', 'S6', 'S7', 'S8'],
        'name': ['Scarlette Fisher', 'Carla Williamson', 'Dante Morse', 'Kaiser William', 'Madeeha Preston'],
        'marks': [201, 200, 198, 219, 201]})

# %% [markdown]
# #####11. Write a Pandas program to join the two given dataframes along rows and assign all data.

# %%
### code here
pd.concat([student_data1,student_data2])
# Out:
#   student_id              name  marks
# 0         S1  Danniella Fenton    200
# 1         S2      Ryder Storey    210
# 2         S3      Bryce Jensen    190
# 3         S4         Ed Bernal    222
# 4         S5       Kwame Morin    199
# 0         S4  Scarlette Fisher    201
# 1         S5  Carla Williamson    200
# 2         S6       Dante Morse    198
# 3         S7    Kaiser William    219
# 4         S8   Madeeha Preston    201

# %% [markdown]
# ##### 12. Write a Pandas program to join the two given dataframes along columns and assign all data.

# %%
### code here
pd.concat([student_data1,student_data2],axis=1)
# Out:
#   student_id              name  marks student_id              name  marks
# 0         S1  Danniella Fenton    200         S4  Scarlette Fisher    201
# 1         S2      Ryder Storey    210         S5  Carla Williamson    200
# 2         S3      Bryce Jensen    190         S6       Dante Morse    198
# 3         S4         Ed Bernal    222         S7    Kaiser William    219
# 4         S5       Kwame Morin    199         S8   Madeeha Preston    201

# %% [markdown]
# ##### 13. Write a Pandas program to join the two dataframes using the common column of both dataframes.

# %%
### code here
pd.merge(student_data1,student_data2,on='student_id')
# Out:
#   student_id       name_x  marks_x            name_y  marks_y
# 0         S4    Ed Bernal      222  Scarlette Fisher      201
# 1         S5  Kwame Morin      199  Carla Williamson      200

# %% [markdown]
# ###### 14. Write a Pandas program to join (left join) the two dataframes using keys from left dataframe only.

# %%
### code here
pd.merge(student_data1, student_data2, on='student_id', how='left')
# Out:
#   student_id            name_x  marks_x            name_y  marks_y
# 0         S1  Danniella Fenton      200               NaN      NaN
# 1         S2      Ryder Storey      210               NaN      NaN
# 2         S3      Bryce Jensen      190               NaN      NaN
# 3         S4         Ed Bernal      222  Scarlette Fisher    201.0
# 4         S5       Kwame Morin      199  Carla Williamson    200.0

# %% [markdown]
# ###### 15. Write a Pandas program to join two dataframes using keys from right dataframe only.

# %%
### code here
pd.merge(student_data1, student_data2, on='student_id', how='right')
# Out:
#   student_id       name_x  marks_x            name_y  marks_y
# 0         S4    Ed Bernal    222.0  Scarlette Fisher      201
# 1         S5  Kwame Morin    199.0  Carla Williamson      200
# 2         S6          NaN      NaN       Dante Morse      198
# 3         S7          NaN      NaN    Kaiser William      219
# 4         S8          NaN      NaN   Madeeha Preston      201

# %% [markdown]
# ###### import UFO dataset

# %%
ufo = pd.read_csv('ufo_sighting_data.csv')
# Out:
# <ipython-input-58-15073a951fc4>:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo = pd.read_csv('ufo_sighting_data.csv')

# %%
ufo.head()
# Out:
#           Date_time                  city state/province country UFO_shape  \
# 0  10/10/1949 20:30            san marcos             tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb             tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3  10/10/1956 21:00                  edna             tx      us    circle
# 4  10/10/1960 20:00               kaneohe             hi      us     light
#
#   length_of_encounter_seconds described_duration_of_encounter  \
# 0                        2700                      45 minutes
# 1                        7200                         1-2 hrs
# 2                          20                      20 seconds
# 3                          20                        1/2 hour
# 4                         900                      15 minutes
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...       4/27/2004
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2  Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3  My older brother and twin sister were leaving ...       1/17/2004
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
#
#      latitude   longitude
# 0  29.8830556  -97.941111
# 1    29.38421  -98.581082
# 2        53.2   -2.916667
# 3  28.9783333  -96.645833
# 4  21.4180556 -157.803611

# %% [markdown]
# ######16. Write a Pandas program to create the todays date.

# %%
### code here
today = pd.to_datetime('today')
today
# Out:
# Timestamp('2025-04-01 08:25:33.710732')

# %% [markdown]
# ###### 17. Write a Pandas program to get the current date, oldest date and number of days between Current date and oldest date of Ufo dataset.

# %%
#### code here
current_date = pd.to_datetime('today')
oldest_date = pd.to_datetime(ufo['Date_time'], errors = 'coerce').min()
number_of_days = (current_date - oldest_date).days
print(f'Current date: {current_date}')
print(f'Oldest date: {oldest_date}')
print(f'Number of days between Current date and oldest date: {number_of_days}')
# Out:
# Current date: 2025-04-01 09:04:04.322048
# Oldest date: 1906-11-11 00:00:00
# Number of days between Current date and oldest date: 43241

# %% [markdown]
# ###### 18. Write a Pandas program to get all the info of the dataframe between 1950-10-10 and 1960-10-10.

# %%
### code here
ufo['Date_time'] = pd.to_datetime(ufo['Date_time'], errors = 'coerce')
ufo[(ufo['Date_time'] >= '1950-10-10') & (ufo['Date_time'] <= '1960-10-10')]
# Out:
#                 Date_time                  city state/province country  \
# 2     1955-10-10 17:00:00  chester (uk/england)            NaN      gb
# 3     1956-10-10 21:00:00                  edna             tx      us
# 480   1952-10-01 03:30:00       fukuoka (japan)            NaN     NaN
# 481   1952-10-01 12:00:00           kansas city             mo      us
# 482   1954-10-01 19:00:00             flatwoods             wv      us
# ...                   ...                   ...            ...     ...
# 79262 1960-09-05 21:00:00               buffalo             ny      us
# 79668 1958-09-07 19:00:00                arthur             nd      us
# 80101 1952-09-09 20:00:00          philadelphia             pa      us
# 80102 1954-09-09 12:30:00              beaumont             tx      us
# 80103 1956-09-09 05:55:00               norfolk             va      us
#
#       UFO_shape length_of_encounter_seconds described_duration_of_encounter  \
# 2        circle                          20                      20 seconds
# 3        circle                          20                        1/2 hour
# 480        disk                        1200                   about 20 mins
# 481        disk                          90                         90 sec.
# 482      circle                          60                        1 minute
# ...         ...                         ...                             ...
# 79262      oval                       180.0                       3 minutes
# 79668   unknown                       900.0                       5-15 min.
# 80101    circle                       180.0                       3 minutes
# 80102      disk                       300.0                       5 minutes
# 80103     cigar                        90.0                     1.5 minutes
#
#                                              description date_documented  \
# 2      Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3      My older brother and twin sister were leaving ...       1/17/2004
# 480    UFO seen by multiple U. S. military personnel;...       12/7/2006
# 481    1952 daylight sighting of multiple discs in fo...      10/31/2008
# 482    I saw the craft go across the horizon.  It app...       4/12/2013
# ...                                                  ...             ...
# 79262  Precise movements of a &quot;craft&quot; appar...       9/15/2005
# 79668  Two lights of alternating color traveling and ...      10/31/2003
# 80101                   saucers in a line over Phila Pa.      12/12/2009
# 80102  Aprox. 30 Disk shaped UFOs fell out of clouds ...       1/17/2004
# 80103  Unidentified Object Hovering over Interstate 2...       2/24/2007
#
#          latitude   longitude
# 2            53.2   -2.916667
# 3      28.9783333  -96.645833
# 480     33.590355  130.401716
# 481    39.0997222  -94.578333
# 482    38.7230556  -80.650000
# ...           ...         ...
# 79262   42.886389  -78.878611
# 79668   47.104167  -97.217778
# 80101   39.952222  -75.164167
# 80102   30.085833  -94.101667
# 80103   36.846667  -76.285556
#
# [444 rows x 11 columns]
